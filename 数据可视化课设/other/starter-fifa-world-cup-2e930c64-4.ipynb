# %% [markdown]
# ## Introduction
# Greetings from the Kaggle bot! This is an automatically-generated kernel with starter code demonstrating how to read in the data and begin exploring. Click the blue "Edit Notebook" or "Fork Notebook" button at the top of this kernel to begin editing.

# %% [markdown]
# ## Exploratory Analysis
# To begin this exploratory analysis, first use `matplotlib` to import libraries and define functions for plotting the data. Depending on the data, not all plots will be made. (Hey, I'm just a kerneling bot, not a Kaggle Competitions Grandmaster!)

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
plt.rc("font", family='Microsoft YaHei')

# %% [markdown]
# There are 3 csv files in the current version of the dataset:

# %% [markdown]
# The next hidden code cells define functions for plotting data. Click on the "Code" button in the published kernel to reveal the hidden code.

# %%
# Distribution graphs (histogram/bar graph) of column data
def plotPerColumnDistribution(df, nGraphShown, nGraphPerRow):
    nunique = df.nunique()
    df = df[[col for col in df if nunique[col] > 1 and nunique[col] < 50]] # For displaying purposes, pick columns that have between 1 and 50 unique values
    nRow, nCol = df.shape
    columnNames = list(df)
    nGraphRow = (nCol + nGraphPerRow - 1) / nGraphPerRow
    plt.figure(num = None, figsize = (6 * nGraphPerRow, 8 * nGraphRow), dpi = 80, facecolor = 'w', edgecolor = 'k')
    for i in range(min(nCol, nGraphShown)):
        plt.subplot(nGraphRow, nGraphPerRow, i + 1)
        columnDf = df.iloc[:, i]
        if (not np.issubdtype(type(columnDf.iloc[0]), np.number)):
            valueCounts = columnDf.value_counts()
            valueCounts.plot.bar()
        else:
            columnDf.hist()
        plt.ylabel('counts')
        plt.xticks(rotation = 90)
        plt.title(f'{columnNames[i]} (column {i})')
    plt.tight_layout(pad = 1.0, w_pad = 1.0, h_pad = 1.0)
    plt.savefig('相关性矩阵1')
    plt.show()

# %%
# Correlation matrix
def plotCorrelationMatrix(df, graphWidth):
    filename = df.dataframeName
    df = df.dropna('columns') # drop columns with NaN
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    if df.shape[1] < 2:
        print(f'No correlation plots shown: The number of non-NaN or constant columns ({df.shape[1]}) is less than 2')
        return
    corr = df.corr()
    plt.figure(num=None, figsize=(graphWidth, graphWidth), dpi=80, facecolor='w', edgecolor='b')
    corrMat = plt.matshow(corr, fignum = 1)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
    plt.yticks(range(len(corr.columns)), corr.columns)
    plt.gca().xaxis.tick_bottom()
    plt.colorbar(corrMat)
    plt.title('WorldCups相关性矩阵分析', fontsize=15)
    plt.savefig('相关性矩阵3')
    plt.show()

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %% [markdown]
# Now you're ready to read in the data and use the plotting functions to visualize the data.

# %% [markdown]
# ### Let's check 1st file: ../input/WorldCupMatches.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# WorldCupMatches.csv has 4573 rows in reality, but we are only loading/previewing the first 1000 rows
df1 = pd.read_csv('./data/WorldCupMatches.csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'WorldCupMatches.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 20 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df1.head(5)
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# 1                    18346.0                   2.0                   0.0
# 2                    24059.0                   2.0                   0.0
# 3                     2549.0                   1.0                   0.0
# 4                    23409.0                   0.0                   0.0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)    201.0   1096.0                FRA
# 1       WARNKEN Alberto (CHI)    201.0   1090.0                USA
# 2         BALWAY Thomas (FRA)    201.0   1093.0                YUG
# 3    MATEUCCI Francisco (URU)    201.0   1098.0                ROU
# 4  RADULESCU Constantin (ROU)    201.0   1085.0                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df1, 10, 5)
# Out:
# <ipython-input-44-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)
# <ipython-input-44-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)
# <ipython-input-44-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df1, 8)
# Out:
# No correlation plots shown: The number of non-NaN or constant columns (0) is less than 2

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(world_cup_matches, 20, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-050524077468> in <module>
# ----> 1 plotScatterMatrix(world_cup_matches, 20, 10)
#
# <ipython-input-19-45d7bdcfca59> in plotScatterMatrix(df, plotSize, textSize)
#       9         columnNames = columnNames[:10]
#      10     df = df[columnNames]
# ---> 11     ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
#      12     corrs = df.corr().values
#      13     for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     126     """
#     127     plot_backend = _get_plot_backend("matplotlib")
# --> 128     return plot_backend.scatter_matrix(
#     129         frame=frame,
#     130         alpha=alpha,
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      37     n = df.columns.size
#      38     naxes = n * n
# ---> 39     fig, axes = create_subplots(naxes=naxes, figsize=figsize, ax=ax, squeeze=False)
#      40
#      41     # no gaps between subplots
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_matplotlib\tools.py in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     242
#     243     # Create first subplot separately, so we can share it if requested
# --> 244     ax0 = fig.add_subplot(nrows, ncols, 1, **subplot_kw)
#     245
#     246     if sharex:
#
# D:\Anaconda\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# D:\Anaconda\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# D:\Anaconda\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     674                 cbook.warn_deprecated("3.3", message=message)
#     675                 rows, cols = map(int, [rows, cols])
# --> 676             gs = GridSpec(rows, cols, figure=figure)
#     677             if isinstance(num, tuple) and len(num) == 2:
#     678                 if not all(isinstance(n, Integral) for n in num):
#
# D:\Anaconda\lib\site-packages\matplotlib\gridspec.py in __init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     418         self.figure = figure
#     419
# --> 420         GridSpecBase.__init__(self, nrows, ncols,
#     421                               width_ratios=width_ratios,
#     422                               height_ratios=height_ratios)
#
# D:\Anaconda\lib\site-packages\matplotlib\gridspec.py in __init__(self, nrows, ncols, height_ratios, width_ratios)
#      49                 f"Number of rows must be a positive integer, not {nrows}")
#      50         if not isinstance(ncols, Integral) or ncols <= 0:
# ---> 51             raise ValueError(
#      52                 f"Number of columns must be a positive integer, not {ncols}")
#      53         self._nrows, self._ncols = nrows, ncols
#
# ValueError: Number of columns must be a positive integer, not 0

# %% [markdown]
# ### Let's check 2nd file: ../input/WorldCupPlayers.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
# WorldCupPlayers.csv has 37785 rows in reality, but we are only loading/previewing the first 1000 rows
df2 = pd.read_csv('./data/WorldCupPlayers.csv', delimiter=',', nrows = nRowsRead)
df2.dataframeName = 'WorldCupPlayers.csv'
nRow, nCol = df2.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 1000 rows and 9 columns

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df2.head(5)
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df2, 10, 5)
# Out:
# <ipython-input-17-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)
# <ipython-input-17-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)
# <ipython-input-17-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)
# <ipython-input-17-f43396a301c0>:10: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   plt.subplot(nGraphRow, nGraphPerRow, i + 1)

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df2, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c630283018cd> in <module>
# ----> 1 plotCorrelationMatrix(df2, 8)
#
# TypeError: plotCorrelationMatrix() missing 1 required positional argument: 'filename'

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(df2, 9, 10)

# %% [markdown]
# ### Let's check 3rd file: ../input/WorldCups.csv

# %%
nRowsRead = 1000 # specify 'None' if want to read whole file
df3 = pd.read_csv('./data/WorldCups.csv', delimiter=',', nrows = nRowsRead)
df3.dataframeName = 'WorldCups.csv'
nRow, nCol = df3.shape
print(f'There are {nRow} rows and {nCol} columns')

# %% [markdown]
# Let's take a quick look at what the data looks like:

# %%
df3.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-1ed26fdf25c8> in <module>
# ----> 1 df3.head(5)
#
# NameError: name 'df3' is not defined

# %% [markdown]
# Distribution graphs (histogram/bar graph) of sampled columns:

# %%
plotPerColumnDistribution(df3, 10, 5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-ea7cbfde32d4> in <module>
# ----> 1 plotPerColumnDistribution(df3, 10, 5)
#
# NameError: name 'df3' is not defined

# %% [markdown]
# Correlation matrix:

# %%
plotCorrelationMatrix(df3, 8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-fb773d2045fc> in <module>
# ----> 1 plotCorrelationMatrix(df3, 8)
#
# NameError: name 'df3' is not defined

# %% [markdown]
# Scatter and density plots:

# %%
plotScatterMatrix(df3, 15, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-7147a9028b44> in <module>
# ----> 1 plotScatterMatrix(df3, 15, 10)
#
# NameError: name 'df3' is not defined

# %% [markdown]
# ## Conclusion
# This concludes your starter analysis! To go forward from here, click the blue "Edit Notebook" button at the top of the kernel. This will create a copy of the code and environment for you to edit. Delete, modify, and add code as you please. Happy Kaggling!
